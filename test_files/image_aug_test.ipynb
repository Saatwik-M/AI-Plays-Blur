# %%
from imgaug import augmenters as iaa
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('test_save/sim_1/436.png', 1)[:,:,::-1]

# %%
plt.imshow(image)

# %%
aug = iaa.Multiply((0.8, 1.2), per_channel=0.5)
plt.imshow(aug.augment_image(image))

# %%
image.shape
# Out:
# (1080, 1920, 3)
